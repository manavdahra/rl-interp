# %% [markdown]
# ## Interpreting DQN network with social attention

# %%
# %pip install plotly nbformat shap transformer_lens
# Out:
# MDAHRAS-MACBOOK-PRO.LOCAL-M-7XH9-M-7XH9-M-7XH9-M-7XH9-M-7XH9
# Requirement already satisfied: plotly in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (5.24.1)
# Requirement already satisfied: nbformat in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (5.10.4)
# Requirement already satisfied: shap in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (0.46.0)
# Requirement already satisfied: transformer_lens in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (2.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from plotly) (24.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: numpy in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from shap) (1.15.1)
# Requirement already satisfied: scikit-learn in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from shap) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from shap) (3.1.1)
# Requirement already satisfied: accelerate>=0.23.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (1.3.0)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (0.0.3)
# Requirement already satisfied: datasets>=2.7.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (3.2.0)
# Requirement already satisfied: einops>=0.6.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (0.8.0)
# Requirement already satisfied: fancy-einsum>=0.0.3 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (0.2.36)
# Requirement already satisfied: rich>=12.6.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (13.9.4)
# Requirement already satisfied: sentencepiece in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (0.2.0)
# Requirement already satisfied: torch!=2.0,!=2.1.0,>=1.10 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (2.5.1)
# Requirement already satisfied: transformers>=4.37.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (4.48.1)
# Requirement already satisfied: typeguard<5.0,>=4.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (4.4.1)
# Requirement already satisfied: typing-extensions in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (4.12.2)
# Requirement already satisfied: wandb>=0.13.5 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformer_lens) (0.19.4)
# Requirement already satisfied: psutil in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer_lens) (6.1.1)
# Requirement already satisfied: pyyaml in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer_lens) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer_lens) (0.27.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from accelerate>=0.23.0->transformer_lens) (0.5.2)
# Requirement already satisfied: filelock in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens) (19.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens) (2.32.3)
# Requirement already satisfied: xxhash in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.7.1->transformer_lens) (2024.9.0)
# Requirement already satisfied: aiohttp in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from datasets>=2.7.1->transformer_lens) (3.11.11)
# Requirement already satisfied: attrs>=22.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rich>=12.6.0->transformer_lens) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rich>=12.6.0->transformer_lens) (2.19.1)
# Requirement already satisfied: networkx in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (3.1.5)
# Requirement already satisfied: setuptools in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformers>=4.37.2->transformer_lens) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from transformers>=4.37.2->transformer_lens) (0.21.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from wandb>=0.13.5->transformer_lens) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from wandb>=0.13.5->transformer_lens) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from wandb>=0.13.5->transformer_lens) (3.1.44)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from wandb>=0.13.5->transformer_lens) (5.29.3)
# Requirement already satisfied: pydantic<3,>=2.6 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from wandb>=0.13.5->transformer_lens) (2.10.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from wandb>=0.13.5->transformer_lens) (2.20.0)
# Requirement already satisfied: setproctitle in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from wandb>=0.13.5->transformer_lens) (1.3.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.4.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from docker-pycreds>=0.4.0->wandb>=0.13.5->transformer_lens) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.7.1->transformer_lens) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.7.1->transformer_lens) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.7.1->transformer_lens) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.7.1->transformer_lens) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.7.1->transformer_lens) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from aiohttp->datasets>=2.7.1->transformer_lens) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer_lens) (4.0.12)
# Requirement already satisfied: mdurl~=0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer_lens) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.13.5->transformer_lens) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.13.5->transformer_lens) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.7.1->transformer_lens) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jinja2->torch!=2.0,!=2.1.0,>=1.10->transformer_lens) (3.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.13.5->transformer_lens) (5.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install rl-agents@git+https://github.com/manavdahra/rl-agents#egg=rl-agents
# %pip install highway-env@git+https://github.com/manavdahra/highway-env#egg=highway-env
# Out:
# MDAHRAS-MACBOOK-PRO.LOCAL-M-7XH9-M-7XH9-M-7XH9-M-7XH9-M-7XH9
# Collecting rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents
#   Cloning https://github.com/manavdahra/rl-agents to /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-ro__gdut/rl-agents_3ed8c6fd0cb9465480697a9bc628a8ea
#   Running command git clone --filter=blob:none --quiet https://github.com/manavdahra/rl-agents /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-ro__gdut/rl-agents_3ed8c6fd0cb9465480697a9bc628a8ea
#   Resolved https://github.com/manavdahra/rl-agents to commit b65a875cd76c2b58a6124ed95235d041896667fe
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting highway_env@ git+https://github.com/manavdahra/highway-env (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents)
#   Cloning https://github.com/manavdahra/highway-env to /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-ro__gdut/highway-env_a3aa074647e247b8b4cc3be801bd8053
#   Running command git clone --filter=blob:none --quiet https://github.com/manavdahra/highway-env /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-ro__gdut/highway-env_a3aa074647e247b8b4cc3be801bd8053
#   Resolved https://github.com/manavdahra/highway-env to commit 304f67efae94a7a0b5a1a8e95cad450e3f5a5b8c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.0.0)
# Requirement already satisfied: numpy in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.26.4)
# Requirement already satisfied: pandas in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2.2.3)
# Requirement already satisfied: numba in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (0.60.0)
# Requirement already satisfied: pygame in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2.6.1)
# Requirement already satisfied: matplotlib in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (3.10.0)
# Requirement already satisfied: seaborn in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (0.13.2)
# Requirement already satisfied: six in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.17.0)
# Requirement already satisfied: docopt in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (0.6.2)
# Requirement already satisfied: torch>=1.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2.5.1)
# Requirement already satisfied: tensorboard in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2.18.0)
# Requirement already satisfied: tensorboardX in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2.6.2.2)
# Requirement already satisfied: scipy in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.15.1)
# Requirement already satisfied: filelock in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (4.12.2)
# Requirement already satisfied: networkx in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (3.1.5)
# Requirement already satisfied: fsspec in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2024.9.0)
# Requirement already satisfied: setuptools in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (3.1.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (0.0.4)
# Requirement already satisfied: moviepy>=1.0.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2.1.2)
# Requirement already satisfied: opencv-python>=3.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (4.11.0.86)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from numba->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2024.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (5.29.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (3.1.3)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (2.36.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (0.1.10)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (3.0.2)
# Requirement already satisfied: tqdm in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents#egg=rl-agents) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.
# MDAHRAS-MACBOOK-PRO.LOCAL-M-7XH9-M-7XH9-M-7XH9-M-7XH9-M-7XH9
# Collecting highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env
#   Cloning https://github.com/manavdahra/highway-env to /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-peihtlsp/highway-env_591b4eccb82f46c2acc0eeac2b430a7b
#   Running command git clone --filter=blob:none --quiet https://github.com/manavdahra/highway-env /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-peihtlsp/highway-env_591b4eccb82f46c2acc0eeac2b430a7b
#   Resolved https://github.com/manavdahra/highway-env to commit 304f67efae94a7a0b5a1a8e95cad450e3f5a5b8c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium>=1.0.0a2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (1.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (1.26.4)
# Requirement already satisfied: pygame>=2.0.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (2.6.1)
# Requirement already satisfied: matplotlib in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (3.10.0)
# Requirement already satisfied: pandas in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (2.2.3)
# Requirement already satisfied: scipy in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (1.15.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium>=1.0.0a2->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium>=1.0.0a2->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env#egg=highway-env) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Library imports

# %%
import torch
import numpy as np
import gymnasium as gym
import highway_env
import plotly.express as px

from pathlib import Path
from rl_agents.agents.deep_q_network.pytorch import DQNAgent

gym.register_envs(highway_env)
torch.manual_seed(123)
np.random.seed(123)

# %%
from rl_agents.agents.common.factory import load_agent, load_environment

env_config = 'config/env.json'
agent_config = 'config/agents/DQNAgent/ego_attention_4h.json'

env = load_environment(env_config)
agent = load_agent(agent_config, env)
# Out:
# /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning:
#
# WARN: The environment intersection-v0 is out of date. You should consider upgrading to version `v1`.
#
# [WARNING] Preferred device cuda:best unavailable, switching to default cpu

# %% [markdown]
# ## Train agent

# %%
from rl_agents.trainer.evaluation import Evaluation

evaluation = Evaluation(
    env, 
    agent, 
    num_episodes=500, 
    display_env=False, 
    display_agent=False,
    recover=True,
    directory="../../output/intersection-v0/ego-attention"
)
evaluation.train()

# %% [markdown]
# ## Load and Evaluate model

# %%
def load_agent_model(model_path):
    try:
        model_path = agent.load(filename=model_path)
        if model_path:
            print("Loaded {} model from {}".format(agent.__class__.__name__, model_path))
    except NotImplementedError:
        pass

load_agent_model("../../output/intersection-v0/ego-attention/saved_models/latest.tar")
# Out:
# Loaded DQNAgent model from ../../output/intersection-v0/ego-attention/saved_models/latest.tar
# /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages/rl_agents/agents/deep_q_network/pytorch.py:89: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %% [markdown]
# ## Evaluate agent

# %%
import base64
from IPython import display as ipythondisplay

def show_videos(path="videos"):
    html = []
    for mp4 in Path(path).glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                      loop controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
from rl_agents.trainer.evaluation import Evaluation
evaluation = Evaluation(env, agent, num_episodes=10, training = False, recover = False)
evaluation.test()
show_videos(evaluation.run_directory)
# Out:
# [INFO] Episode 0 score: 0.0
# [INFO] Episode 1 score: -0.6
# [INFO] Episode 2 score: 0.0
# [INFO] Episode 3 score: 5.0
# [INFO] Episode 4 score: -1.3
# [INFO] Episode 5 score: 9.0
# [INFO] Episode 6 score: 9.0
# [INFO] Episode 7 score: 9.0
# [INFO] Episode 8 score: -2.5
# [INFO] Episode 9 score: 9.0
# <video alt="out/IntersectionEnv/DQNAgent/run_20250124-142242_53875/rl-video-episode-8.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video><br><video alt="out/IntersectionEnv/DQNAgent/run_20250124-142242_53875/rl-video-episode-0.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video><br><video alt="out/IntersectionEnv/DQNAgent/run_20250124-142242_53875/rl-video-episode-1.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %% [markdown]
# ## Analysis and interpretation
#
# - Agent analyzer will run agent and record it's activations, activity to draw some key insights
# - Analyse the agent's architecture

# %%
from collections import defaultdict
from PIL import Image

def render_images(images):
    for image in images:
        Image.fromarray(image).show()

class ModelAnalyzer:
    def __init__(self, agent: DQNAgent, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.agent = agent
        self.reset()

    def reset(self):
        if hasattr(self, 'hooks'):
            for hook in self.hooks:
                hook.remove()

        state, _ = env.reset()
        self.states = [state]
        self.actions = []
        self.activations = defaultdict(list)
        self.hooks = []
        self.done = False
        self.attention_matrix = []
        self.images = []
        self.total_reward = 0
        
        self._register_hooks(self.agent.value_net)

    def step(self):
        action = self.agent.act(self.states[-1])
        self.actions.append(action)
        state, reward, done, truncated, _ = env.step(action)
        self.total_reward += reward
        self.done = done or truncated
        self.images.append(env.render())
        self._record(state)

    def stats(self):
        print(f"Total reward: {self.total_reward}")
        print(f"States: {len(self.states)}")
        print(f"Actions: {len(self.actions)}")
        print(f"Attention matrices: {len(self.attention_matrix)}")
        print(f"images: {len(self.images)}")

        for key in self.activations:
            print(f"Activations for {key}: {len(self.activations[key])}")
    
    def _record(self, obs):
        self.states.append(obs)
        state = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
        self.attention_matrix.append(self.agent.value_net.get_attention_matrix(state).detach())
            
    def _register_hooks(self, module: torch.nn.Module):
        for name, sub_module in module.named_modules():
            if isinstance(sub_module, torch.nn.Linear):
                self.hooks.append(sub_module.register_forward_hook(self._get_activation(name)))
        
    
    def _get_activation(self, name):
        def hook(module, args, output):
            self.activations[name].append(output.detach())
        
        return hook

# %% [markdown]
# ### Check the agent architecture

# %%
print(evaluation.agent.value_net)
# Out:
# EgoAttentionNetwork(
#   (ego_embedding): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0): Linear(in_features=7, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (others_embedding): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0): Linear(in_features=7, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (attention_layer): EgoAttention(
#     (value_all): Linear(in_features=64, out_features=64, bias=False)
#     (key_all): Linear(in_features=64, out_features=64, bias=False)
#     (query_ego): Linear(in_features=64, out_features=64, bias=False)
#     (attention_combine): Linear(in_features=64, out_features=64, bias=False)
#   )
#   (output_layer): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=64, out_features=64, bias=True)
#     )
#     (predict): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ### Run analyzer using the agent

# %%
analyzer = ModelAnalyzer(agent)

while not analyzer.done:
    analyzer.step()

analyzer.stats()
# Out:
# Total reward: 9.0
# States: 10
# Actions: 9
# Attention matrices: 9
# images: 9
# Activations for ego_embedding.layers.0: 297
# Activations for ego_embedding.layers.1: 297
# Activations for others_embedding.layers.0: 297
# Activations for others_embedding.layers.1: 297
# Activations for attention_layer.key_all: 297
# Activations for attention_layer.value_all: 297
# Activations for attention_layer.query_ego: 297
# Activations for attention_layer.attention_combine: 297
# Activations for output_layer.layers.0: 279
# Activations for output_layer.layers.1: 279
# Activations for output_layer.predict: 279

# %% [markdown]
# ## Observation
# - Feature optimization
# - Logit lens on attention mechanism
# - Circuit analysis on actions
#
# ## Intervention
# - Path tracing
#
# ## Explainable RL
# - Discovering symbolic policies on Deep RL networks. [Source](https://proceedings.mlr.press/v139/landajuela21a/landajuela21a.pdf)
#
# ### Attention pattern

# %%
import torch.nn.functional as F
import plotly.graph_objects as go
from plotly.subplots import make_subplots

untrained_agent = load_agent(agent_config, env)

def analyze_qk_circuit(value_net):
    query_layer = value_net.attention_layer.query_ego
    key_layer = value_net.attention_layer.key_all
    q_wt = query_layer.weight.detach().view(1, 64, 64).transpose(-2, -1)
    k_wt = key_layer.weight.detach().view(1, 64, 64)
    
    return F.softmax(torch.matmul(q_wt, k_wt), dim=-1)

def analyze_ov_circuit(value_net):
    value_layer = value_net.attention_layer.value_all
    output_later = value_net.attention_layer.attention_combine
    val_wt = value_layer.weight.detach().view(1, 64, 64)
    out_wt = output_later.weight.detach().view(1, 64, 64)
    
    return torch.matmul(out_wt, val_wt)

def analyze_embedding_weights(embedding):
    embedding_layer_0 = embedding.layers[0].weight.detach().T
    embedding_layer_1 = embedding.layers[1].weight.detach()
    
    return torch.matmul(embedding_layer_0, embedding_layer_1)

def analyze_embedding_biases(embedding):
    embedding_layer_0 = embedding.layers[0].bias.detach()
    embedding_layer_1 = embedding.layers[1].bias.detach()
    
    return [embedding_layer_0, embedding_layer_1]

def compute_diff(a: torch.Tensor, b: torch.Tensor):
    return ((a - b)**2).numpy()

def compare_qk_circuit(untrained_agent, trained_agent):
    untrained_qk_circuit = analyze_qk_circuit(untrained_agent.value_net)
    trained_qk_circuit = analyze_qk_circuit(trained_agent.value_net)

    heads = untrained_qk_circuit.size(0)
    for h in range(heads):
        fig = make_subplots(rows=1, cols=3, subplot_titles=("Untrained", "Trained", "Difference"))
        fig.add_trace(go.Heatmap(z=untrained_qk_circuit[h].numpy(), coloraxis="coloraxis"), row=1, col=1)
        fig.add_trace(go.Heatmap(z=trained_qk_circuit[h].numpy(), coloraxis="coloraxis"), row=1, col=2)
        fig.add_trace(go.Heatmap(z=compute_diff(trained_qk_circuit[h], untrained_qk_circuit[h]), coloraxis="coloraxis"), row=1, col=3)
        fig.update_layout(title_text=f"Attention head: {h+1} QK Circuits", coloraxis=dict(colorscale="RdBu"))
        fig.show()
    
def compare_ov_circuit(untrained_agent, trained_agent):
    untrained_ov_circuit = analyze_ov_circuit(untrained_agent.value_net)
    trained_ov_circuit = analyze_ov_circuit(trained_agent.value_net)

    heads = untrained_ov_circuit.size(0)
    for h in range(heads):
        fig = make_subplots(rows=1, cols=3, subplot_titles=("Untrained", "Trained", "Difference"))
        fig.add_trace(go.Heatmap(z=untrained_ov_circuit[h].numpy(), coloraxis="coloraxis"), row=1, col=1)
        fig.add_trace(go.Heatmap(z=trained_ov_circuit[h].numpy(), coloraxis="coloraxis"), row=1, col=2)
        fig.add_trace(go.Heatmap(z=compute_diff(trained_ov_circuit[h], untrained_ov_circuit[h]), coloraxis="coloraxis"), row=1, col=3)
        fig.update_layout(title_text=f"Attention head: {h+1} OV Circuits", coloraxis=dict(colorscale="RdBu"))
        fig.show()
    

compare_qk_circuit(untrained_agent, analyzer.agent)
compare_ov_circuit(untrained_agent, analyzer.agent)
# Out:
# [WARNING] Preferred device cuda:best unavailable, switching to default cpu

# %% [markdown]
# Above comparisions are between QK and OV circuits of untrained and trained agents with MSE difference in values.
# A quick look reveals that indeed the agent learned some structure/pattern of taking actions which helps in avoiding crashes with other vehicles.
#
# Observations of structure:
# - Regularised patterns with gaps in between. It's worth studying whether these gaps change if the environment settings change.
# - It is also visible that the weight patterns alternate between high and low activations. Why ?
# - QK circuit reveals that the Neurons 10 and 41 have high attention weights assigned, qualifying them as candidates for further analysis.
# - OV circuit reveals a clear activation for few neurons again with alternating patterns.
#
# > TODO: understand these patterns and try to make some conclusions about them

# %% [markdown]
# ### Analyze Embedding matrices
# Next, let's analyze the embedding matrices of the agent's architecture which sits before Attention layer of the transformers. These matrices are crucial in understanding as to what the agent thinks are important features, this will guide us in the right direction of applying interpretability techniques.

# %%
def compare_ego_embeddings_matrix(untrained_agent, trained_agent):
    untrained_ego_embeddings_wt = analyze_embedding_weights(untrained_agent.value_net.ego_embedding)
    trained_ego_embeddings_wt = analyze_embedding_weights(trained_agent.value_net.ego_embedding)

    features = ["presence", "x", "y", "vx", "vy", "cos_h", "sin_h"]
    fig = make_subplots(rows=1, cols=3, subplot_titles=("Untrained", "Trained"))
    fig.add_trace(go.Heatmap(z=untrained_ego_embeddings_wt, coloraxis="coloraxis", y=features), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_ego_embeddings_wt, coloraxis="coloraxis", y=features), row=1, col=2)
    fig.add_trace(go.Heatmap(z=compute_diff(trained_ego_embeddings_wt, untrained_ego_embeddings_wt), coloraxis="coloraxis", y=features), row=1, col=3)
    fig.update_layout(
        title_text="Ego Embeddings Matrix", 
        coloraxis=dict(colorscale="RdBu"), 
    )
    fig.show()

    untrained_ego_embeddins_b = analyze_embedding_biases(untrained_agent.value_net.ego_embedding)
    trained_ego_embeddings_b = analyze_embedding_biases(trained_agent.value_net.ego_embedding)

    fig = make_subplots(rows=1, cols=2)
    fig.add_trace(go.Bar(x=features, y=torch.abs(trained_ego_embeddings_b[0] - untrained_ego_embeddins_b[0]), name="Layer 0 Biases diff"), row=1, col=1)
    fig.add_trace(go.Bar(x=features, y=torch.abs(trained_ego_embeddings_b[1] - untrained_ego_embeddins_b[1]), name="Layer 1 Biases diff"), row=1, col=2)
    fig.update_layout(title_text="Ego Embeddings Biases")
    fig.show()

def compare_others_embeddings_matrix(untrained_agent, trained_agent):
    untrained_others_embeddings_wt = analyze_embedding_weights(untrained_agent.value_net.others_embedding)
    trained_others_embeddings_wt = analyze_embedding_weights(trained_agent.value_net.others_embedding)

    features = ["presence", "x", "y", "vx", "vy", "cos_h", "sin_h"]
    fig = make_subplots(rows=1, cols=3, subplot_titles=("Untrained", "Trained"))
    fig.add_trace(go.Heatmap(z=untrained_others_embeddings_wt, coloraxis="coloraxis", y=features), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_others_embeddings_wt, coloraxis="coloraxis", y=features), row=1, col=2)
    fig.add_trace(go.Heatmap(z=compute_diff(trained_others_embeddings_wt, untrained_others_embeddings_wt), coloraxis="coloraxis", y=features), row=1, col=3)
    fig.update_layout(
        title_text="Others Embeddings Matrix", 
        coloraxis=dict(colorscale="RdBu"), 
    )
    fig.show()

    untrained_others_embeddins_b = analyze_embedding_biases(untrained_agent.value_net.others_embedding)
    trained_others_embeddings_b = analyze_embedding_biases(trained_agent.value_net.others_embedding)

    fig = make_subplots(rows=1, cols=2)
    fig.add_trace(go.Bar(x=features, y=torch.abs(trained_others_embeddings_b[0] - untrained_others_embeddins_b[0]), name="Layer 0 Biases diff"), row=1, col=1)
    fig.add_trace(go.Bar(x=features, y=torch.abs(trained_others_embeddings_b[1] - untrained_others_embeddins_b[1]), name="Layer 1 Biases diff"), row=1, col=2)
    fig.update_layout(title_text="Others Embeddings Biases")
    fig.show()

compare_ego_embeddings_matrix(untrained_agent, analyzer.agent)
compare_others_embeddings_matrix(untrained_agent, analyzer.agent)

# %% [markdown]
# Above graphs hint at the possibility that the agent's ego embedding layer (responsible for tracking observations of itself) has learnt to assign more weights to features - `y`, `vx`, `x` etc, in the decreasing order of their importance.
# On the other hand, agent's others embedding layer (responsible for tracking observations of other vehicles) has learnt to assign more weights to the feature `vx`, `x` etc.
#
# Qualitatively, that seems reasonable. In order for the agent to make a successful turn at the intersection, the agent needs to track following key information:
# - Vertical position of itself. Most likely the agent has learnt to slow down as it's `y` coordinate (increases) reaches closer to the intersection, conversely speed up when it is far away from intersection.
# - Horizontal velocity of the other vehicles `vx`. This seems more important as agent learns to wait at the intersection when a vehicle is crossing the intersection at high speed. Thereby increasing its chances of avoiding collision.
# - Other features like `presence` and `x` also show medium level weights values.
#
# > Studying absolute differences of biases between untrained and trained models don't reveal any good insights. Maybe a different approach of analyzing them may reveal better insights.

# %% [markdown]
# ### MLP Layer analysis

# %%
def analyze_mlp_hidden_weights(agent):
    output_layer = agent.value_net.output_layer
    wt_layer_0 = output_layer.layers[0].weight.detach().T
    wt_layer_1 = output_layer.layers[1].weight.detach()

    return torch.matmul(wt_layer_0, wt_layer_1)

def compare_mlp_layer(untrained_agent, trained_agent):
    untrained_mlp_layer = analyze_mlp_hidden_weights(untrained_agent)
    trained_mlp_layer = analyze_mlp_hidden_weights(trained_agent)

    fig = make_subplots(rows=1, cols=3, subplot_titles=("Untrained", "Trained", "Difference"))
    fig.add_trace(go.Heatmap(z=untrained_mlp_layer, coloraxis="coloraxis"), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_mlp_layer, coloraxis="coloraxis"), row=1, col=2)
    fig.add_trace(go.Heatmap(z=compute_diff(trained_mlp_layer, untrained_mlp_layer), coloraxis="coloraxis"), row=1, col=3)
    fig.update_layout(title_text="MLP Layer", coloraxis=dict(colorscale="RdBu"))
    fig.show()

compare_mlp_layer(untrained_agent, analyzer.agent)

# Step: 257, Perturbation: 0.09943853318691254
# Step: 258, Perturbation: 0.09943853318691254
# Step: 259, Perturbation: 0.09943853318691254
# Step: 260, Perturbation: 0.09943853318691254
# Step: 261, Perturbation: 0.09943853318691254
# Step: 262, Perturbation: 0.09943853318691254
# Step: 263, Perturbation: 0.09943853318691254
# Step: 264, Perturbation: 0.09943853318691254
# Step: 265, Perturbation: 0.09943853318691254
# Step: 266, Perturbation: 0.09943853318691254
# Step: 267, Perturbation: 0.09943853318691254
# Step: 268, Perturbation: 0.09943853318691254
# Step: 269, Perturbation: 0.09943853318691254
# Step: 270, Perturbation: 0.09943853318691254
# Step: 271, Perturbation: 0.09943853318691254
# Step: 272, Perturbation: 0.09943853318691254
# Step: 273, Perturbation: 0.09943853318691254
# Step: 274, Perturbation: 0.09943853318691254
# Step: 275, Perturbation: 0.09943853318691254
# Step: 276, Perturbation: 0.09943853318691254
# Step: 277, Perturbation: 0.09943853318691254
# Step: 278, Perturbation: 0.09943853318691254

# %% [markdown]
# ### Logit Lens

# %%
### TODO apply logit lens technique here ###

# %% [markdown]
# ## SHAP technique

# %%
### TODO apply shapley values here ###

# %% [markdown]
# ### Activation analysis

# %%
def attn_scores(query: torch.Tensor, key: torch.Tensor):
    d_k = query.size(-1)
    return F.softmax(torch.matmul(query, key.transpose(-2, -1)) / np.sqrt(d_k), dim=-1)

# %% [markdown]
# ```
# Total reward: 10.0
# States: 11
# Actions: 10
# Attention matrices: 10
# images: 10
# Activations for ego_embedding.layers.0: 330
# Activations for ego_embedding.layers.1: 330
# Activations for others_embedding.layers.0: 330
# Activations for others_embedding.layers.1: 330
# Activations for attention_layer.key_all: 330
# Activations for attention_layer.value_all: 330
# Activations for attention_layer.query_ego: 330
# Activations for attention_layer.attention_combine: 330
# Activations for output_layer.layers.0: 310
# Activations for output_layer.layers.1: 310
# Activations for output_layer.predict: 310
# ```

# %%
def analyze_activations(analyzer):
    activations = analyzer.activations

    q_acts = activations['attention_layer.query_ego']
    k_acts = activations['attention_layer.key_all']
    v_acts = activations['attention_layer.value_all']

    for i in range(150, 160):
        fig = make_subplots(rows=1, cols=2, subplot_titles=("Attn scores", "Scene"))
        scores = attn_scores(q_acts[i].repeat(1, k_acts[i].size(1), 1), k_acts[i]).squeeze(0).numpy()
        fig.add_trace(go.Heatmap(z=scores, coloraxis="coloraxis"), row=1, col=1)
        fig.add_trace(go.Image(z=analyzer.images[i//30]), row=1, col=2)
        fig.update_layout(title_text=f"Step: {i}", coloraxis=dict(colorscale="RdBu"))
        fig.show()


def analyze_actions(analyzer):
    predict_acts = analyzer.activations["output_layer.predict"]
    critical_actions = [
        0, # slower 
        1, # idle
    ]
    critical_steps = []
    print(analyzer.actions)
    for step, action in enumerate(analyzer.actions):
        if action in critical_actions:
            critical_steps.append((step-1, action))

    for step, action in critical_steps:
        px.imshow(analyzer.images[step], title=f"Step: {step}").show()
        # print(IntersectionEnv.ACTIONS[action], predict_acts[step])
        px.imshow(predict_acts[step], title=f"Predicted actions: {step}").show()

analyze_activations(analyzer)
# analyze_actions(analyzer)
