# %% [markdown]
# ## Interpreting DQN network with social attention

# %%
# %pip install rl-agents@git+https://github.com/manavdahra/rl-agents
# %pip install highway-env@git+https://github.com/manavdahra/highway-env
# %pip install plotly nbformat
# Out:
# mdahras-MacBook-Pro.local
# Collecting rl-agents@ git+https://github.com/manavdahra/rl-agents
#   Cloning https://github.com/manavdahra/rl-agents to /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-5xxus69n/rl-agents_4e02728afd874d7c9da144ae50a58c69
#   Running command git clone --filter=blob:none --quiet https://github.com/manavdahra/rl-agents /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-5xxus69n/rl-agents_4e02728afd874d7c9da144ae50a58c69
#   Resolved https://github.com/manavdahra/rl-agents to commit b65a875cd76c2b58a6124ed95235d041896667fe
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting highway_env@ git+https://github.com/manavdahra/highway-env (from rl-agents@ git+https://github.com/manavdahra/rl-agents)
#   Cloning https://github.com/manavdahra/highway-env to /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-5xxus69n/highway-env_66a7433271cf4bacbd5c70e96b5c30cc
#   Running command git clone --filter=blob:none --quiet https://github.com/manavdahra/highway-env /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-5xxus69n/highway-env_66a7433271cf4bacbd5c70e96b5c30cc
#   Resolved https://github.com/manavdahra/highway-env to commit 304f67efae94a7a0b5a1a8e95cad450e3f5a5b8c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.0.0)
# Requirement already satisfied: numpy in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.26.4)
# Requirement already satisfied: pandas in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (2.2.3)
# Requirement already satisfied: numba in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (0.60.0)
# Requirement already satisfied: pygame in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (2.6.1)
# Requirement already satisfied: matplotlib in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (3.10.0)
# Requirement already satisfied: seaborn in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (0.13.2)
# Requirement already satisfied: six in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.17.0)
# Requirement already satisfied: docopt in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (0.6.2)
# Requirement already satisfied: torch>=1.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (2.5.1)
# Requirement already satisfied: tensorboard in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (2.18.0)
# Requirement already satisfied: tensorboardX in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (2.6.2.2)
# Requirement already satisfied: scipy in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.15.1)
# Requirement already satisfied: filelock in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents) (4.12.2)
# Requirement already satisfied: networkx in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents) (3.1.5)
# Requirement already satisfied: fsspec in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents) (2024.12.0)
# Requirement already satisfied: setuptools in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.2.0->rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium->rl-agents@ git+https://github.com/manavdahra/rl-agents) (3.1.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium->rl-agents@ git+https://github.com/manavdahra/rl-agents) (0.0.4)
# Requirement already satisfied: moviepy>=1.0.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents) (2.1.2)
# Requirement already satisfied: opencv-python>=3.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents) (4.11.0.86)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->rl-agents@ git+https://github.com/manavdahra/rl-agents) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from numba->rl-agents@ git+https://github.com/manavdahra/rl-agents) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->rl-agents@ git+https://github.com/manavdahra/rl-agents) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->rl-agents@ git+https://github.com/manavdahra/rl-agents) (2024.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents) (5.29.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents) (3.1.3)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents) (2.36.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents) (0.1.10)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->rl-agents@ git+https://github.com/manavdahra/rl-agents) (3.0.2)
# Requirement already satisfied: tqdm in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[other]->rl-agents@ git+https://github.com/manavdahra/rl-agents) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.
# mdahras-MacBook-Pro.local
# Collecting highway-env@ git+https://github.com/manavdahra/highway-env
#   Cloning https://github.com/manavdahra/highway-env to /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-ozpqn2w8/highway-env_0875b3b57c5f46b0b01a4cba9dc85fd4
#   Running command git clone --filter=blob:none --quiet https://github.com/manavdahra/highway-env /private/var/folders/40/b3pz_mbj6bl7vh33p2tyg6j00000gn/T/pip-install-ozpqn2w8/highway-env_0875b3b57c5f46b0b01a4cba9dc85fd4
#   Resolved https://github.com/manavdahra/highway-env to commit 304f67efae94a7a0b5a1a8e95cad450e3f5a5b8c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gymnasium>=1.0.0a2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env) (1.0.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env) (0.0.4)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env) (1.26.4)
# Requirement already satisfied: pygame>=2.0.2 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env) (2.6.1)
# Requirement already satisfied: matplotlib in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env) (3.10.0)
# Requirement already satisfied: pandas in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env) (2.2.3)
# Requirement already satisfied: scipy in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from highway-env@ git+https://github.com/manavdahra/highway-env) (1.15.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium>=1.0.0a2->highway-env@ git+https://github.com/manavdahra/highway-env) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from gymnasium>=1.0.0a2->highway-env@ git+https://github.com/manavdahra/highway-env) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->highway-env@ git+https://github.com/manavdahra/highway-env) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from pandas->highway-env@ git+https://github.com/manavdahra/highway-env) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->highway-env@ git+https://github.com/manavdahra/highway-env) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# mdahras-MacBook-Pro.local
# Requirement already satisfied: plotly in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (5.24.1)
# Requirement already satisfied: nbformat in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (5.10.4)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from plotly) (24.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: typing-extensions>=4.4.0 in /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Library imports

# %%
import torch
import numpy as np
import gymnasium as gym
import highway_env
import plotly.express as px

from pathlib import Path
from rl_agents.agents.deep_q_network.pytorch import DQNAgent

gym.register_envs(highway_env)
torch.manual_seed(123)
np.random.seed(123)

# %% [markdown]
# ## Load trained agent

# %%
from rl_agents.trainer.evaluation import Evaluation
from rl_agents.agents.common.factory import load_agent, load_environment

env_config = 'config/env.json'
agent_config = 'config/agents/DQNAgent/ego_attention_4h.json'

env = load_environment(env_config)
agent = load_agent(agent_config, env)
evaluation = Evaluation(
    env, 
    agent, 
    num_episodes=100, 
    display_env=False, 
    display_agent=False,
    recover=True,
    directory="../../output/intersection-v0/ego-attention"
)
print(f"Ready to evaluate and interpret {agent} on {env}")
# Out:
# /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment intersection-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# Preferred device cuda:best unavailable, switching to default cpu
# /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages/rl_agents/agents/deep_q_network/pytorch.py:89: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, map_location=self.device)
# [INFO] Loaded DQNAgent model from ../../output/intersection-v0/ego-attention/saved_models/latest.tar
# Ready to evaluate and interpret <rl_agents.agents.deep_q_network.pytorch.DQNAgent object at 0x103240f20> on <OrderEnforcing<PassiveEnvChecker<IntersectionEnv<intersection-v0>>>>

# %% [markdown]
# ## Evaluate agent

# %%
import base64
from IPython import display as ipythondisplay

def show_videos(path="videos"):
    html = []
    for mp4 in Path(path).glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                      loop controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
evaluation = Evaluation(env, agent, num_episodes=20, training = False, recover = True)
evaluation.test()
show_videos(evaluation.run_directory)
# Out:
# [WARNING] No pre-trained model found at the desired location.
# 2025-01-18 21:27:14.503 Python[73821:5037005] +[IMKClient subclass]: chose IMKClient_Modern
# /Users/mdahra/workspace/machine-learning/rl-interp/.venv/lib/python3.12/site-packages/rl_agents/agents/deep_q_network/pytorch.py:80: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
#   return self.value_net(torch.tensor(states, dtype=torch.float).to(self.device)).data.cpu().numpy()
# [INFO] Episode 0 score: 9.0
# [INFO] Episode 1 score: -1.0
# [INFO] Episode 2 score: 10.0
# [INFO] Episode 3 score: -1.0
# [INFO] Episode 4 score: 9.0
# [INFO] Episode 5 score: 9.0
# [INFO] Episode 6 score: 9.0
# [INFO] Episode 7 score: -1.0
# [INFO] Episode 8 score: 9.0
# [INFO] Episode 9 score: 9.0
# [INFO] Episode 10 score: 9.0
# [INFO] Episode 11 score: -1.0
# [INFO] Episode 12 score: -1.0
# [INFO] Episode 13 score: -0.3
# [INFO] Episode 14 score: 10.0
# [INFO] Episode 15 score: 1.0
# [INFO] Episode 16 score: -1.0
# [INFO] Episode 17 score: -1.0
# [INFO] Episode 18 score: -1.0
# [INFO] Episode 19 score: 10.0
# <video alt="out/IntersectionEnv/DQNAgent/run_20250118-212713_73821/rl-video-episode-8.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video><br><video alt="out/IntersectionEnv/DQNAgent/run_20250118-212713_73821/rl-video-episode-0.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video><br><video alt="out/IntersectionEnv/DQNAgent/run_20250118-212713_73821/rl-video-episode-1.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %% [markdown]
# ## Analysis and interpretation
#
# - Agent analyzer will run agent and record it's activations, activity to draw some key insights
# - Analyse the agent's architecture

# %%
from collections import defaultdict
from PIL import Image

def render_images(images):
    for image in images:
        Image.fromarray(image).show()

class ModelAnalyzer:
    def __init__(self, agent: DQNAgent, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.agent = agent
        self.reset()

    def reset(self):
        if hasattr(self, 'hooks'):
            for hook in self.hooks:
                hook.remove()

        self.states = []
        self.activations = defaultdict(list)
        self.hooks = []
        self.done = False
        self.previous_state, _ = env.reset()
        self.attention_matrix = []
        self.images = []
        
        self._register_hooks(self.agent.value_net)

    def step(self):
        if self.done:
            self.reset()
            return

        action = self.agent.act(self.previous_state)
        state, _, done, truncated, _ = env.step(action)
        self.done = done or truncated
        self.images.append(env.render())
        self._record(state)
    
    def _record(self, obs):
        self.states.append(obs)
        state = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
        self.attention_matrix.append(self.agent.value_net.get_attention_matrix(state).detach())
            
    def _register_hooks(self, module: torch.nn.Module):
        for name, sub_module in module.named_modules():
            if isinstance(sub_module, torch.nn.Linear):
                self.hooks.append(sub_module.register_forward_hook(self._get_activation(name)))
        
    
    def _get_activation(self, name):
        def hook(module, args, output):
            self.activations[name].append(output.detach())
        
        return hook

# %% [markdown]
# ### DQN with Social attention architecture

# %%
print(agent.value_net)
# Out:
# EgoAttentionNetwork(
#   (ego_embedding): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0): Linear(in_features=7, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (others_embedding): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0): Linear(in_features=7, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (attention_layer): EgoAttention(
#     (value_all): Linear(in_features=64, out_features=64, bias=False)
#     (key_all): Linear(in_features=64, out_features=64, bias=False)
#     (query_ego): Linear(in_features=64, out_features=64, bias=False)
#     (attention_combine): Linear(in_features=64, out_features=64, bias=False)
#   )
#   (output_layer): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=64, out_features=64, bias=True)
#     )
#     (predict): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ### Render a random scene

# %% [markdown]
# ### Run analyzer using the agent

# %%
analyzer = ModelAnalyzer(agent)

while not analyzer.done:
    analyzer.step()

# %%
for img, q_act in zip(analyzer.images, analyzer.activations["attention_layer.query_ego"]):
    print(q_act.shape)
    print(img.shape)
# Out:
# torch.Size([1, 1, 64])
# (600, 1200, 3)
# torch.Size([1, 1, 64])
# (600, 1200, 3)
# torch.Size([1, 1, 64])
# (600, 1200, 3)
# torch.Size([1, 1, 64])
# (600, 1200, 3)
# torch.Size([1, 1, 64])
# (600, 1200, 3)
# torch.Size([1, 1, 64])
# (600, 1200, 3)
# torch.Size([1, 1, 64])
# (600, 1200, 3)
# torch.Size([1, 1, 64])
# (600, 1200, 3)
# torch.Size([1, 1, 64])
# (600, 1200, 3)
# torch.Size([1, 1, 64])
# (600, 1200, 3)

# %% [markdown]
# ### Attention pattern

# %%
def analyze_attention_weights(analyzer):
    
    query_layer = analyzer.agent.value_net.attention_layer.query_ego
    key_layer = analyzer.agent.value_net.attention_layer.key_all
    value_layer = analyzer.agent.value_net.attention_layer.value_all
    attn_layer = analyzer.agent.value_net.attention_layer.attention_combine

    q_wt = next(query_layer.parameters()).detach().numpy()
    k_wt = next(key_layer.parameters()).detach().numpy()
    v_wt = next(value_layer.parameters()).detach().numpy()
    attn_mat = analyzer.attention_matrix.squeeze(0).squeeze(1)

    print(attn_mat.shape)
    px.imshow(np.dot(q_wt, k_wt.T), title="QK weights", color_continuous_scale="RdBu").show()
    px.imshow(attn_mat, title="Attention weights", color_continuous_scale="RdBu").show()
    
analyze_attention_weights(analyzer)

# %% [markdown]
# ### Activation analysis

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def analyze_activations(analyzer):
    activations = analyzer.activations
    q_ego = activations["ego_embedding.layers.1"]
    q_oth = activations["others_embedding.layers.1"]

    q_act = activations["attention_layer.query_ego"]
    k_act = activations["attention_layer.key_all"]
    v_act = activations["attention_layer.value_all"]
    attn_combine = activations["attention_layer.attention_combine"]

    print(q_ego[0,0])
    print(q_act[0,0])
    # qk = q @ k.T
    # px.imshow(qk, title="QK circuit", color_continuous_scale="Rdbu").show()
    # px.imshow(attn_combine, title="Attn combined", color_continuous_scale="RdBu").show()

print(analyzer.agent.value_net)
analyze_activations(analyzer)
