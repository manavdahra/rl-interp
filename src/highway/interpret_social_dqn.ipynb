# %% [markdown]
# # Interpreting autonomous driving agents with attention based architecture

# %% [markdown]
# ### Install customised code from forked repositories.
#
# These include bug fixing related to the environment setup which are necessary to run this experiment

# %% [markdown]
# ## Library imports

# %%
import torch
import numpy as np
import gymnasium as gym
import highway_env
import plotly.express as px

from pathlib import Path
from rl_agents.trainer.evaluation import Evaluation
from rl_agents.agents.deep_q_network.pytorch import DQNAgent
from rl_agents.agents.common.factory import load_agent, load_environment

gym.register_envs(highway_env)
torch.manual_seed(123)
np.random.seed(123)
# Out:
# /Users/vasudharajain/workspace/rl-interp/.venv/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# /Users/vasudharajain/workspace/rl-interp/.venv/lib/python3.12/site-packages/rl_agents/agents/common/utils.py:103: SyntaxWarning: invalid escape sequence '\|'
#   m = re.findall("\| *[0-9] *" + str(pid) + " *C *.*python.*? +([0-9]+).*\|", result, re.MULTILINE)
# /Users/vasudharajain/workspace/rl-interp/.venv/lib/python3.12/site-packages/rl_agents/agents/common/utils.py:103: SyntaxWarning: invalid escape sequence '\|'
#   m = re.findall("\| *[0-9] *" + str(pid) + " *C *.*python.*? +([0-9]+).*\|", result, re.MULTILINE)
# ...

# %% [markdown]
# ## Initialise agent with configuration
#
# This initialises the agent with randomised empty weights

# %%
env_config = "config/env.json"
agent_config = "config/agents/DQNAgent/ego_attention_4h.json"

env = load_environment(env_config)
agent = load_agent(agent_config, env)
# Out:
# /Users/vasudharajain/workspace/rl-interp/.venv/lib/python3.12/site-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment intersection-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(
# Preferred device cuda:best unavailable, switching to default cpu

# %% [markdown]
# ## Train agent
#
# Train the agent from scratch for 1000 episodes.
#
# We train without loading the previous states and store the latest trained weights in directory

# %%
evaluation = Evaluation(
    env, 
    agent, 
    num_episodes=1000, 
    display_env=False, 
    display_agent=False,
    recover=False,
    directory="../../output/intersection-v0/ego-attention"
)
evaluation.train()
# Out:
# /Users/vasudharajain/workspace/rl-interp/.venv/lib/python3.12/site-packages/rl_agents/agents/deep_q_network/pytorch.py:80: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   return self.value_net(torch.tensor(states, dtype=torch.float).to(self.device)).data.cpu().numpy()
# [INFO] Episode 0 score: -3.2
# [INFO] Saved DQNAgent model to ../../output/intersection-v0/ego-attention/run_20251221-005400_77723/checkpoint-0.tar
# [INFO] Episode 1 score: -1.0
# [INFO] Saved DQNAgent model to ../../output/intersection-v0/ego-attention/run_20251221-005400_77723/checkpoint-1.tar
# [INFO] Episode 2 score: 8.6
# [INFO] Episode 3 score: -3.3
# [INFO] Episode 4 score: 5.2
# [INFO] Episode 5 score: 8.6
# [INFO] Episode 6 score: 2.5
# ...

# %% [markdown]
# ## Load agent
#
# If working from a different session in this notebook. Run the following cell to load the latest saved state of the model from the local directory.

# %%
def load_agent_model(agent, model_path):
    try:
        model_path = agent.load(filename=model_path)
        if model_path:
            print("Loaded {} model from {}".format(agent.__class__.__name__, model_path))
    except NotImplementedError:
        pass

load_agent_model(agent, "../../output/intersection-v0/ego-attention/run_20251221-005400_77723/checkpoint-final.tar")
# Out:
# Loaded DQNAgent model from ../../output/intersection-v0/ego-attention/run_20251221-005400_77723/checkpoint-final.tar

# %% [markdown]
# ## Evaluate agent

# %% [markdown]
# ### Setup a utility method to allow rendering of videos in the notebook itself

# %%
import base64
from IPython import display as ipythondisplay

def show_videos(path="videos"):
    html = []
    for mp4 in Path(path).glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                      loop controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %% [markdown]
# ### Evaluate the agent
#
# Run a small sample of evaluations to check if the agent really learned to drive.

# %%
from rl_agents.trainer.evaluation import Evaluation
evaluation = Evaluation(env, agent, num_episodes=10, training = False, recover = False)
evaluation.test()
# show_videos(evaluation.run_directory)

# %% [markdown]
# ## Observations and Analysis
#
# First let's check the agent's architecture.
#
# The agent has two neural nets - `target_net` and `value_net` (also called q-network or prediction network that outputs predictions) as it uses a DQN reinforcement learning algorithm.
#
# Target net and Q-net are identical in architecture. This is because DQN algorithm recommends updating the weights of Value net from target net after certain number of episodes. This is done to ensure that the agent's is trained while avoiding catastrophic forgetting.
#
# More on this can be found [here](https://huggingface.co/learn/deep-rl-course/en/unit3/deep-q-algorithm)

# %% [markdown]
# Target net architecture

# %%
print(agent.target_net)
# Out:
# EgoAttentionNetwork(
#   (ego_embedding): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0): Linear(in_features=7, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (others_embedding): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0): Linear(in_features=7, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (attention_layer): EgoAttention(
#     (value_all): Linear(in_features=64, out_features=64, bias=False)
#     (key_all): Linear(in_features=64, out_features=64, bias=False)
#     (query_ego): Linear(in_features=64, out_features=64, bias=False)
#     (attention_combine): Linear(in_features=64, out_features=64, bias=False)
#   )
#   (output_layer): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=64, out_features=64, bias=True)
#     )
#     (predict): Linear(in_features=64, out_features=3, bias=True)
# ...

# %% [markdown]
# Value net (Q-net) architecture

# %%
print(agent.value_net)
# Out:
# EgoAttentionNetwork(
#   (ego_embedding): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0): Linear(in_features=7, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (others_embedding): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0): Linear(in_features=7, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#   )
#   (attention_layer): EgoAttention(
#     (value_all): Linear(in_features=64, out_features=64, bias=False)
#     (key_all): Linear(in_features=64, out_features=64, bias=False)
#     (query_ego): Linear(in_features=64, out_features=64, bias=False)
#     (attention_combine): Linear(in_features=64, out_features=64, bias=False)
#   )
#   (output_layer): MultiLayerPerceptron(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=64, out_features=64, bias=True)
#     )
#     (predict): Linear(in_features=64, out_features=3, bias=True)
# ...

# %% [markdown]
# ### Define inputs and outputs of the agent for analysis

# %%
# Define features/observations and actions
features = ["presence", "x", "y", "vx", "vy", "cos_h", "sin_h"]
actions_map = {
    0: "SLOWER",
    1: "IDLE",
    2: "FASTER",
}

# %% [markdown]
# ### Model analyzer
#
# Now let's define a class that does the following:
# 1. Encapsulates the agent
# 2. Registers forward hooks to capture activations of each linear layer and records scene images.
# 3. Runs evaluations and prints statistics.

# %%
from collections import defaultdict
from PIL import Image

untrained_agent = load_agent(agent_config, env)

def render_images(images):
    for image in images:
        Image.fromarray(image).show()

class ModelAnalyzer:
    def __init__(self, agent: DQNAgent, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.agent = agent
        self.reset()

    def reset(self):
        state, _ = env.reset()
        self.states = [state]
        self.steps = 0
        self.actions = []
        self.done = False
        self.attention_matrix = []
        self.images = []
        self.total_reward = 0

    def run(self):
        self.reset()
        activations = defaultdict(list)

        self.agent.eval()
        def get_activation(name):
            def hook(module, input, output):
                activations[name].append(output.detach())
            
            return hook
    
        hooks = []
        for name, sub_module in self.agent.value_net.named_modules():
            if isinstance(sub_module, torch.nn.Linear):
                hooks.append(sub_module.register_forward_hook(get_activation(name)))

        while not self.done:
            self.step()
        
        for hook in hooks:
            hook.remove()

        return activations, self.stats()

    def step(self):
        action = self.agent.act(self.states[-1])
        self.actions.append(action)
        state, reward, done, truncated, _ = env.step(action)
        self.total_reward += reward
        self.done = done or truncated
        self.images.append(env.render())
        self._record(state)

    def stats(self):
        return {
            "total_reward": self.total_reward,
            "steps": len(self.states),
            "states": len(self.states),
            "actions": len(self.actions),
            "attention_matrices": len(self.attention_matrix),
            "images": len(self.images),
        }
    
    def _record(self, obs):
        self.states.append(obs)
        state = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
        self.attention_matrix.append(self.agent.value_net.get_attention_matrix(state).detach())

# %% [markdown]
# ### Run analyzer on trained agent and print stats

# %%
analyzer = ModelAnalyzer(agent)
activations, stats = analyzer.run()
print(stats)

# %%
def print_actions(analyzer):
    print("Actions sequence: ", [actions_map[a] for a in analyzer.actions])
print_actions(analyzer)

# %% [markdown]
# ## Interpretation of the agent
# The process of interpretation of the agent model can be broken down into 2 major categories:
# - Interpretation by Obersvation
# - Interpreation by Intervention
#
# ### Observations:
# - Attention layer QK and OV circuits
#     - Add explanations and some theory [Attention heads](https://transformer-circuits.pub/2021/framework/index.html#:~:text=CONCEPTUAL%20TAKE%2DAWAYS)
# - Study feature importance using captum
#     - Explain integrated gradients approach [Integrated graidents](https://arxiv.org/pdf/1703.01365)
#     - Explain neuron conductance approach: [Neuron conductance](https://arxiv.org/pdf/1805.12233)
# - Plot neuron activations
#     - Motivation and reasoning for viewing individual neurons behaviour
# - Logit lens on attention mechanism
#     - Explainer
#
# - Semantic dictionary - TODO
#     - Explain what this means and why we need this
# - Feature optimization - TODO
#     - Exaplainer
#     - Render a scene with given input observations
# - Circuit analysis on actions - TODO
# - Tensor-to-tensor visualisation - TODO
#
# ### Intervention:
# - Ablation - TODO
# - Model Editing - TODO
# - Path tracing - TODO

# %% [markdown]
# **Utility functions for analysis**

# %%
import torch.nn.functional as F
def cosine_similarity(a: torch.Tensor, b: torch.Tensor):
    return F.cosine_similarity(a, b).numpy()

def compute_square_diff(a: torch.Tensor, b: torch.Tensor):
    return (a - b).pow(2).numpy()

def compute_diff(a: torch.Tensor, b: torch.Tensor):
    return (a - b).abs().numpy()

# %% [markdown]
# ### QK and OV Circuits
#
# This method is inspired by the previous research done by Anthropic on Query-Key and Output-Value Circuits of transformer layer models.
#
# > Attention heads can be understood as having two largely independent computations: a QK (“query-key”) circuit which computes the attention pattern, and an OV (“output-value”) circuit which computes how each token affects the output if attended to.

# %%
agent.value_net.output_layer

# %%
def analyze_embedding_weights(embedding):
    embedding_layer_0 = embedding.layers[0].weight.detach()
    embedding_layer_1 = embedding.layers[1].weight.detach()
    
    return (embedding_layer_0.T @ embedding_layer_1).detach()

def analyze_unembedding_weights(unembedding):
    unembedding_layer_0 = unembedding.layers[0].weight.detach()
    unembedding_layer_1 = unembedding.layers[1].weight.detach()
    unembedding_layer_predict = unembedding.predict.weight.detach()
    
    return ((unembedding_layer_0 @ unembedding_layer_1.T) @ unembedding_layer_predict.T).detach()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def analyze_attn_scores(value_net):
    query_layer = value_net.attention_layer.query_ego
    key_layer = value_net.attention_layer.key_all
    q_wt = query_layer.weight.detach()
    k_wt = key_layer.weight.detach()
    
    return F.softmax(q_wt.T @ k_wt, dim=-1).detach()

def analyze_ov_scores(value_net):
    value_layer = value_net.attention_layer.value_all
    output_later = value_net.attention_layer.attention_combine
    val_wt = value_layer.weight.detach()
    out_wt = output_later.weight.detach()
    
    return torch.matmul(out_wt, val_wt).detach()

def analyze_qk_circuit(value_net):
    ego_embed_wt = analyze_embedding_weights(value_net.ego_embedding)
    others_embed_wt = analyze_embedding_weights(value_net.others_embedding)
    attn_scores = analyze_attn_scores(value_net)

    ego_ego_qk_circuit = ((ego_embed_wt @ attn_scores) @ ego_embed_wt.T).detach()
    ego_others_qk_circuit = ((ego_embed_wt @ attn_scores) @ others_embed_wt.T).detach()

    return ego_ego_qk_circuit, ego_others_qk_circuit

def analyze_ov_circuit(value_net):
    ego_embed_wt = analyze_embedding_weights(value_net.ego_embedding)
    others_embed_wt = analyze_embedding_weights(value_net.others_embedding)
    unembed_wt = analyze_unembedding_weights(value_net.output_layer)
    ov_scores = analyze_ov_scores(value_net)

    ego_ov_circuit = torch.matmul(torch.matmul(unembed_wt.T, ov_scores), ego_embed_wt.T).detach()
    others_ov_circuit = torch.matmul(torch.matmul(unembed_wt.T, ov_scores), others_embed_wt.T).detach()

    return ego_ov_circuit, others_ov_circuit

def compare_qk_circuits(untrained_agent, trained_agent):
    untrained_ego_qk_circuit, untrained_others_qk_circuit = analyze_qk_circuit(untrained_agent.value_net)
    trained_ego_qk_circuit, trained_others_qk_circuit = analyze_qk_circuit(trained_agent.value_net)

    x, y = features, features
    fig = make_subplots(rows=1, cols=2, subplot_titles=("Untrained", "Trained"))
    fig.add_trace(go.Heatmap(z=untrained_ego_qk_circuit.numpy(), x=x, y=y, coloraxis="coloraxis"), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_ego_qk_circuit.numpy(), x=x, y=y, coloraxis="coloraxis"), row=1, col=2)
    fig.update_layout(
        title_text=f"Attention head: QK Circuits (Ego embeddings)", 
        coloraxis=dict(colorscale="RdBu_r"),
    )
    fig.show()

    fig = make_subplots(rows=1, cols=2, subplot_titles=("Untrained", "Trained"))
    fig.add_trace(go.Heatmap(z=untrained_others_qk_circuit.numpy(), x=x, y=y, coloraxis="coloraxis"), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_others_qk_circuit.numpy(), x=x, y=y, coloraxis="coloraxis"), row=1, col=2)
    fig.update_layout(
        title_text=f"Attention head: QK Circuits (Others embeddings)",
        coloraxis=dict(colorscale="RdBu_r"),
    )
    fig.show()
    

def compare_ov_circuits(untrained_agent, trained_agent):
    untrained_ego_ov_circuit, untrained_others_ov_circuit = analyze_ov_circuit(untrained_agent.value_net)
    trained_ego_ov_circuit, trained_others_ov_circuit = analyze_ov_circuit(trained_agent.value_net)

    x, y = features, ["Slow", "Idle", "Fast"]
    fig = make_subplots(
        rows=2, 
        cols=2, 
        subplot_titles=(
            "Untrained (Ego embedding)", 
            "Trained (Ego embedding)", 
            "Untrained (Others embedding)", 
            "Trained (Others embedding)"
        )
    )
    fig.add_trace(go.Heatmap(z=untrained_ego_ov_circuit.numpy(), x=x, y=y, coloraxis="coloraxis"), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_ego_ov_circuit.numpy(), x=x, y=y, coloraxis="coloraxis"), row=1, col=2)
    fig.add_trace(go.Heatmap(z=untrained_others_ov_circuit.numpy(), x=x, y=y, coloraxis="coloraxis"), row=2, col=1)
    fig.add_trace(go.Heatmap(z=trained_others_ov_circuit.numpy(), x=x, y=y, coloraxis="coloraxis"), row=2, col=2)

    fig.update_layout(title_text=f"Attention head: OV Circuits comparisons", coloraxis=dict(colorscale="RdBu_r"))
    fig.show()

    mean_ov_circuit = (trained_ego_ov_circuit.numpy() + trained_others_ov_circuit.numpy()) / 2
    fig = make_subplots(rows=1, cols=1)
    fig.add_trace(go.Heatmap(z=mean_ov_circuit, x=x, y=y, coloraxis="coloraxis"))
    fig.update_layout(title_text=f"Attention head: OV Circuits (Mean)", coloraxis=dict(colorscale="RdBu_r"))
    fig.show()


def compare_attn_scores(untrained_agent, trained_agent):
    untrained_qk_circuit = analyze_attn_scores(untrained_agent.value_net)
    trained_qk_circuit = analyze_attn_scores(trained_agent.value_net)

    fig = make_subplots(rows=1, cols=3, subplot_titles=("Untrained", "Trained", "Difference"))
    fig.add_trace(go.Heatmap(z=untrained_qk_circuit.numpy(), coloraxis="coloraxis"), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_qk_circuit.numpy(), coloraxis="coloraxis"), row=1, col=2)
    fig.add_trace(go.Heatmap(z=compute_diff(trained_qk_circuit, untrained_qk_circuit), coloraxis="coloraxis"), row=1, col=3)
    fig.update_layout(
        title_text=f"Attention head scores", 
        coloraxis=dict(colorscale="RdBu_r"),
    )
    fig.show()
    
def compare_ov_scores(untrained_agent, trained_agent):
    untrained_ov_circuit = analyze_ov_scores(untrained_agent.value_net)
    trained_ov_circuit = analyze_ov_scores(trained_agent.value_net)

    fig = make_subplots(rows=1, cols=3, subplot_titles=("Untrained", "Trained", "Difference"))
    fig.add_trace(go.Heatmap(z=untrained_ov_circuit.numpy(), coloraxis="coloraxis"), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_ov_circuit.numpy(), coloraxis="coloraxis"), row=1, col=2)
    fig.add_trace(go.Heatmap(z=compute_diff(trained_ov_circuit, untrained_ov_circuit), coloraxis="coloraxis"), row=1, col=3)
    fig.update_layout(title_text=f"Attention head: OV scores", coloraxis=dict(colorscale="RdBu_r"))
    fig.show()
    

compare_attn_scores(untrained_agent, analyzer.agent)
compare_ov_scores(untrained_agent, analyzer.agent)

compare_qk_circuits(untrained_agent, analyzer.agent)
compare_ov_circuits(untrained_agent, analyzer.agent)

# %% [markdown]
# Above comparisions are between QK and OV circuits of untrained and trained agents with Absolute difference in values.
# A quick look reveals that indeed the agent learned some structure/pattern of taking actions which helps in avoiding crashes with other vehicles.
#
# Observations of structure:
# - Certain lines and crossings of higher activations are visible. It's worth studying whether these gaps change if the environment settings change.
# - It is also visible that the weight patterns alternate between high and low activations.
#
# The attention patterns are computed between tensors of 64x64 dimensions which come from residual stream having embedding vectors. It would be worth noting what the embedding vectors represent to understand better what attention patterns mean.

# %% [markdown]
# ## Feature importance
#
# Let's try to find what features are picked up by the embedding layers of the agent and how they are correlated. One approach of studying this is to know what features are most important according to the model.

# %%
inputs = []
activations_batch = []
for _ in range(30):
    activations, _ = analyzer.run()
    activations_batch.append(activations)
    inputs.append(torch.tensor(analyzer.states, dtype=torch.float32).requires_grad_())

# %% [markdown]
# ### Studying the feature importance using Integrated gradients approach
#
# Integrated Gradients is a method for attributing the prediction of a neural network to its input features. It is designed to provide a more accurate and theoretically sound explanation of the model's predictions compared to simpler gradient-based methods.

# %%
from captum.attr import IntegratedGradients
import copy 

def get_feature_importance(net, target):
    ig = IntegratedGradients(net)
    avg_importances = []
    for input in inputs:
        x = torch.tensor(input.detach().numpy(), dtype=torch.float32).requires_grad_()
        attributions, _ = ig.attribute(x, target=target, return_convergence_delta=True)
        attributions = attributions.detach().numpy()
        avg_importances.append(np.mean(attributions, axis=(0, 1)))
    
    return np.mean(avg_importances, axis=0)

def visualize_importances(untrained_value_net, trained_value_net):
    fig = make_subplots(rows=len(actions_map), cols=2, subplot_titles=("Untrained", "Trained"), shared_yaxes=True)

    # Action slower
    untrained_importances = get_feature_importance(untrained_value_net, 0)
    trained_importances = get_feature_importance(trained_value_net, 0)

    fig.add_trace(go.Bar(x=features, y=untrained_importances, name="Untrained agent action: Slower"), row=1, col=1)
    fig.add_trace(go.Bar(x=features, y=trained_importances, name="Trained agent action: Slower"), row=1, col=2)

    # Action idle
    untrained_importances = get_feature_importance(untrained_value_net, 1)
    trained_importances = get_feature_importance(trained_value_net, 1)
    
    fig.add_trace(go.Bar(x=features, y=untrained_importances, name="Untrained agent action: Idle"), row=2, col=1)
    fig.add_trace(go.Bar(x=features, y=trained_importances, name="Trained agent action: Idle"), row=2, col=2)

    # Action faster
    untrained_importances = get_feature_importance(untrained_value_net, 2)
    trained_importances = get_feature_importance(trained_value_net, 2)
    
    fig.add_trace(go.Bar(x=features, y=untrained_importances, name="Untrained agent action: Faster"), row=3, col=1)
    fig.add_trace(go.Bar(x=features, y=trained_importances, name="Trained agent action: Faster"), row=3, col=2)

    fig.update_layout(title_text=f"Feature Importances across multiple runs")
    fig.show()

value_net_copy = copy.deepcopy(analyzer.agent.value_net)
visualize_importances(untrained_agent.value_net, value_net_copy)

# %%
print_actions(analyzer)

# %% [markdown]
# On studying what features on average are learned by the model, show that model indeed learns to track key important features like
# - Presence - Whether a vehicle is present on the road or not
# - x - X coordinate of the vehicle
# - y - Y coordinate of the vehicle
# - cosh & sinh - Trignometric angles of the heading of the vehicle
#
# The average importance of learned feature is compared with an untrained agent copy to verify the results.
#
# Since the agent has 2 different embedding layers -
# Ego embedding layer - reponsible for tracking features for Driving agent in question
# Others embedding layer - responsible for tracking features for Other vehicles
#
# It would be better to analyze features learnt individually in each of the embedding layers.

# %% [markdown]
# ### Analyze Embedding matrices
#
# To visualise what Ego and Others embedding layers capture from the observations. Let us find the embedding matrices.
# In this approach I am calculating the Embedding matrices by the following approach:
#
# $E = W_{L0}^T \cdot W_{L1}$
#
# where, L0 and L1 are embedding layers of the embedding module.
#
# $W_{L0}$ and $W_{L1}$ are weights of those layers with dimensions 7x64 and 64x64 respectively.
#
# Above product gives us a relationship of what input features out of 7 are assigned higher weights when we look at the cumulative weights within the hidden layers.

# %%
def compare_ego_embeddings_matrix(untrained_agent, trained_agent):
    untrained_ego_embeddings_wt = analyze_embedding_weights(untrained_agent.value_net.ego_embedding)
    trained_ego_embeddings_wt = analyze_embedding_weights(trained_agent.value_net.ego_embedding)

    fig = make_subplots(rows=1, cols=3, subplot_titles=("Untrained", "Trained", "Difference"))
    fig.add_trace(go.Heatmap(z=untrained_ego_embeddings_wt, coloraxis="coloraxis", y=features), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_ego_embeddings_wt, coloraxis="coloraxis", y=features), row=1, col=2)
    fig.add_trace(go.Heatmap(z=compute_square_diff(trained_ego_embeddings_wt, untrained_ego_embeddings_wt), coloraxis="coloraxis", y=features), row=1, col=3)
    fig.update_layout(
        title_text="Ego Embeddings Matrix", 
        coloraxis=dict(colorscale="RdBu", reversescale=True), 
    )
    fig.show()

def compare_others_embeddings_matrix(untrained_agent, trained_agent):
    untrained_others_embeddings_wt = analyze_embedding_weights(untrained_agent.value_net.others_embedding)
    trained_others_embeddings_wt = analyze_embedding_weights(trained_agent.value_net.others_embedding)

    features = ["presence", "x", "y", "vx", "vy", "cos_h", "sin_h"]
    fig = make_subplots(rows=1, cols=3, subplot_titles=("Untrained", "Trained", "Difference"))
    fig.add_trace(go.Heatmap(z=untrained_others_embeddings_wt, coloraxis="coloraxis", y=features), row=1, col=1)
    fig.add_trace(go.Heatmap(z=trained_others_embeddings_wt, coloraxis="coloraxis", y=features), row=1, col=2)
    fig.add_trace(go.Heatmap(z=compute_square_diff(trained_others_embeddings_wt, untrained_others_embeddings_wt), coloraxis="coloraxis", y=features), row=1, col=3)
    fig.update_layout(
        title_text="Others Embeddings Matrix", 
        coloraxis=dict(colorscale="RdBu", reversescale=True), 
    )
    fig.show()

compare_ego_embeddings_matrix(untrained_agent, analyzer.agent)
compare_others_embeddings_matrix(untrained_agent, analyzer.agent)

# %% [markdown]
# # TODO: Refine the observations collected here
# Above graphs show that the agent's ego embedding layer (responsible for tracking observations of itself) has learnt to assign more weights to features - `y`, `vx`, `sinh`.
# On the other hand, agent's others embedding layer (responsible for tracking observations of other vehicles) has learnt to assign more weights to the feature `x`, `y`, `vy` and `sinh`.
#
# Qualitatively, that seems reasonable. In order for the agent to make a successful turn at the intersection, the agent needs to track following key information:
# - Vertical position of itself. Most likely the agent has learnt to slow down as it's `y` coordinate (increases) reaches closer to the intersection, conversely speed up when it is far away from intersection.
# - Horizontal velocity of the other vehicles `vx`. This seems more important as agent learns to wait at the intersection when a vehicle is crossing the intersection at high speed. Thereby increasing its chances of avoiding collision.
# - Other features like `presence` and `x` also show medium level weights values.

# %% [markdown]
# Studying feature importance using Layer conductance

# %%
for k in activations.keys():
    print(k)

# %% [markdown]
# ### Layer conductance

# %%
from captum.attr import LayerConductance
import copy 

def get_layer_conductance(net, layer, target):
    cond = LayerConductance(net, layer)
    avg_importances = []
    for input in inputs:
        x = torch.tensor(input.detach().numpy(), dtype=torch.float32).requires_grad_()
        cond_vals = cond.attribute(x, target=target)
        dims = tuple(list(range(len(cond_vals.shape))))
        avg_importances.append(np.mean(cond_vals.detach().numpy(), axis=dims[:-1]))
    
    return np.mean(avg_importances, axis=0)

def analyze_layer_conductances(net, layer, layer_name):
    fig = make_subplots(rows=len(actions_map), cols=1)

    # Action slower
    cond_vals = get_layer_conductance(net, layer, 0)
    fig.add_trace(go.Bar(y=cond_vals, name=f"Neuron activations for Action {actions_map[0]}"), row=1, col=1)
    
    # Action idle
    cond_vals = get_layer_conductance(net, layer, 1)
    fig.add_trace(go.Bar(y=cond_vals, name=f"Neuron activations for Action {actions_map[1]}"), row=2, col=1)

    # Action faster
    cond_vals = get_layer_conductance(net, layer, 2)
    fig.add_trace(go.Bar(y=cond_vals, name=f"Neuron activations for Action {actions_map[2]}"), row=3, col=1)

    fig.update_layout(title_text=f"Layer Conductances for layer: {layer_name}")
    fig.show()

value_net_copy = copy.deepcopy(analyzer.agent.value_net)

analyze_layer_conductances(value_net_copy, value_net_copy.ego_embedding.layers[0], "Ego embedding layer 0")
analyze_layer_conductances(value_net_copy, value_net_copy.ego_embedding.layers[1], "Ego embedding layer 1")

analyze_layer_conductances(value_net_copy, value_net_copy.others_embedding.layers[0], "Others embedding layer 0")
analyze_layer_conductances(value_net_copy, value_net_copy.others_embedding.layers[1], "Others embedding layer 1")
# analyze_layer_conductances(value_net_copy, value_net_copy.output_layer.predict, "predict")

analyze_layer_conductances(value_net_copy, value_net_copy.output_layer.layers[0], "Output layer 0")
analyze_layer_conductances(value_net_copy, value_net_copy.output_layer.layers[1], "Output layer 1")
analyze_layer_conductances(value_net_copy, value_net_copy.output_layer.predict, "predict")

# %% [markdown]
# Embedding layers -
# Studying the activation patterns of Embedding layers, reveal that both Ego and Others embedding layers learn to assign weights to same set of neurons.
# Their activation patterns are almost identical irrespective of the action taken by the model. This makes sense, as embedding layers can be thought of as sensory layers which do not encapsulate agent's decision making process but only as filters of the key important features in the environment.
#
# Output layers -
# After studying the activation patterns of output layers, it shows that the activation patterns of these layers differ minutely on different actions taken.

# %% [markdown]
# ### Neuron conductance

# %%
from captum.attr import NeuronConductance

def get_neuron_conductance(net, layer, neuron, target):
    avg_importances = []
    for input in inputs:
        x = torch.tensor(input.detach().numpy(), dtype=torch.float32).requires_grad_()
        neuron_cond = NeuronConductance(net, layer)
        neuron_cond_vals = neuron_cond.attribute(x, neuron_selector=neuron, target=target)
        neuron_cond_vals = neuron_cond_vals.detach().numpy()
        dims = tuple(list(range(len(neuron_cond_vals.shape))))
        avg_importances.append(np.mean(neuron_cond_vals, axis=dims[:-1]))
    
    return np.mean(avg_importances, axis=0)

def analyze_neuron_conductances(net, layer, layer_name, neuron):
    fig = make_subplots(rows=len(actions_map), cols=1)

    # Action slower
    cond_vals = get_neuron_conductance(net, layer, neuron, 0)
    fig.add_trace(go.Bar(x=features, y=cond_vals), row=1, col=1)

    # Action idle
    cond_vals = get_neuron_conductance(net, layer, neuron, 1)
    fig.add_trace(go.Bar(x=features, y=cond_vals), row=2, col=1)
    
    # Action faster
    cond_vals = get_neuron_conductance(net, layer, neuron, 2)
    fig.add_trace(go.Bar(x=features, y=cond_vals), row=3, col=1)
    
    fig.update_layout(title_text=f"Neuron Conductances for layer: {layer_name} and neuron: {neuron}")
    fig.show()

analyze_neuron_conductances(value_net_copy, value_net_copy.output_layer.layers[0], "Output layer 0", 3)

# %%
def analyze_neuron(layer_name, neurons_range):
    # Extract activations for the neuron
    neuron_activations = np.array([a[(0,) * (a.dim() - 1) + (neurons_range,)].detach().numpy() for a in activations[layer_name]])
    neuron_activations = neuron_activations.transpose()
    
    plot_neuron_activations(neuron_activations, f"Neuron activations for: {layer_name}", [f"neuron {i}" for i in neurons_range])

def plot_neuron_activations(neuron_activations, title, names):
    # plot activations for multiple neurons
    fig = go.Figure()
    for i, activations in enumerate(neuron_activations):
        activations = activations - activations.mean()
        fig.add_trace(go.Scatter(y=activations, mode='lines', name=names[i]))
    fig.update_layout(title=title, xaxis_title="Time step", yaxis_title="Activation")
    fig.show()

analyze_neuron("ego_embedding.layers.0", range(64))
analyze_neuron("ego_embedding.layers.1", range(64))
analyze_neuron("others_embedding.layers.0", range(64))
analyze_neuron("others_embedding.layers.1", range(64))
analyze_neuron("output_layer.layers.0", range(64))
analyze_neuron("output_layer.layers.1", range(64))

# %%
def plot_actions(analyzer):
    analyzer.run()
    step = 0
    actions = analyzer.actions
    next_actions = analyzer.actions[1:]
    heads = analyzer.agent.value_net.config["attention_layer"]["heads"]
    vehicles = 15
    print(analyzer.agent.config)

    
    for action, next_action in zip(actions, next_actions):
        if action == next_action:
            step += 1
            continue

        img = analyzer.images[step]
        attn_matrix = analyzer.attention_matrix[step]

        px.imshow(img, labels={"x": "X-coordinate", "y": "Y-coordinate"}, title=f"Env Scene step: {step} Action: {actions_map[action]}").show()
        px.imshow(attn_matrix.squeeze(0).squeeze(1), y=[f"Head_{h}" for h in range(heads)], x=[f"Vehicle_{v}" for v in range(vehicles)], color_continuous_scale="RdBu_r", title=f"Attention Matrix step: {step} Action: {actions_map[action]}").show()
        
        step += 1

plot_actions(analyzer)

# %% [markdown]
# ### Perturbing activations

# %%
# Function to perturb activations
def perturb_activations(activations, perturbation):
    return activations + perturbation

def analyze_final_layer_perturbations(analyzer):
    for i in range(len(analyzer.activations["output_layer.layers.1"])):
        input = analyzer.activations["output_layer.layers.1"][i].detach()
        org_out = analyzer.agent.value_net.output_layer.predict(input).detach()
        
        pert_in = perturb_activations(input, 0.1)
        pert_out = analyzer.agent.value_net.output_layer.predict(pert_in).detach()
        
        diff = torch.norm(org_out - pert_out, p=2).item()
        print(f"Step: {i}, Perturbation: {diff}")

analyze_final_layer_perturbations(analyzer)

# %% [markdown]
# ### Logit Lens

# %%
def get_output_intermediate_representations(analyzer):
    activations, _ = analyzer.run()
    embedding_layer = analyzer.agent.value_net.output_layer.layers[1]
    linear_layer = torch.nn.Linear(7, 64, bias=False)
    linear_layer.weight = torch.nn.Parameter(embedding_layer.weight.T)
    
    inputs = analyzer.states

    representations = []

    for i, input in enumerate(inputs):
        input = torch.tensor(input, dtype=torch.float32).unsqueeze(0)
        output_layer_act = activations["output_layer.layers.1"][i].detach()[0]
        
        output = linear_layer(output_layer_act)

        input = input.squeeze(0).detach().numpy()
        output = output.detach().numpy()
        representations.append((input, output))

    return representations

def get_embedding_intermediate_representations(analyzer):
    activations, _ = analyzer.run()
    embedding_layer = analyzer.agent.value_net.ego_embedding.layers[0]
    linear_layer = torch.nn.Linear(7, 64, bias=False)
    linear_layer.weight = torch.nn.Parameter(embedding_layer.weight.T)
    
    inputs = analyzer.states

    representations = []

    for i, input in enumerate(inputs):
        input = torch.tensor(input, dtype=torch.float32).unsqueeze(0)
        ego_embedding_act = activations["ego_embedding.layers.1"][i].detach()[0]
        others_embedding_act = activations["others_embedding.layers.1"][i].detach()[0]
        
        embedding_act = torch.cat((ego_embedding_act, others_embedding_act), dim=0)
        output = linear_layer(embedding_act)

        input = input.squeeze(0).detach().numpy()
        output = output.detach().numpy()
        representations.append((input, output))
        # fig = make_subplots(rows=1, cols=2, subplot_titles=("Input", "Representation"))
        # fig.add_trace(go.Heatmap(z=input, coloraxis="coloraxis"), row=1, col=1)
        # fig.add_trace(go.Heatmap(z=output, coloraxis="coloraxis"), row=1, col=2)
        # fig.update_layout(title_text=f"State vs Embedding at step: {i}", coloraxis=dict(colorscale="RdBu_r"))
        # fig.show()

    return representations

def plot_representations(representations):
    max_frames = 5
    for i, (input, output) in enumerate(representations[:max_frames]):
        env.unwrapped.state = input
        px.imshow(env.render(), labels={"x": "X-coordinate", "y": "Y-coordinate"}, title=f"Input frame: {i}").show()
        env.unwrapped.state = output
        px.imshow(env.render(), labels={"x": "X-coordinate", "y": "Y-coordinate"}, title=f"Representation frame: {i}").show()

# representations = get_embedding_intermediate_representations(analyzer)
representations = get_output_intermediate_representations(analyzer)
plot_representations(representations)

# %% [markdown]
# ### Activation analysis

# %%
def attn_scores(query: torch.Tensor, key: torch.Tensor):
    d_k = query.size(-1)
    return F.softmax(torch.matmul(query, key.transpose(-2, -1)) / np.sqrt(d_k), dim=-1)

# %%
def analyze_activations(analyzer):
    activations = analyzer.activations

    q_acts = activations['attention_layer.query_ego']
    k_acts = activations['attention_layer.key_all']
    v_acts = activations['attention_layer.value_all']

    for i in range(150, 160):
        fig = make_subplots(rows=1, cols=2, subplot_titles=("Attn scores", "Scene"))
        scores = attn_scores(q_acts[i].repeat(1, k_acts[i].size(1), 1), k_acts[i]).squeeze(0).numpy()
        fig.add_trace(go.Heatmap(z=scores, coloraxis="coloraxis"), row=1, col=1)
        fig.add_trace(go.Image(z=analyzer.images[i//30]), row=1, col=2)
        fig.update_layout(title_text=f"Step: {i}", coloraxis=dict(colorscale="RdBu"))
        fig.show()


def analyze_actions(analyzer):
    predict_acts = analyzer.activations["output_layer.predict"]
    critical_actions = [
        0, # slower 
        1, # idle
    ]
    critical_steps = []
    print(analyzer.actions)
    for step, action in enumerate(analyzer.actions):
        if action in critical_actions:
            critical_steps.append((step-1, action))

    for step, action in critical_steps:
        px.imshow(analyzer.images[step], title=f"Step: {step}").show()
        # print(IntersectionEnv.ACTIONS[action], predict_acts[step])
        px.imshow(predict_acts[step], title=f"Predicted actions: {step}").show()

analyze_activations(analyzer)
# analyze_actions(analyzer)
